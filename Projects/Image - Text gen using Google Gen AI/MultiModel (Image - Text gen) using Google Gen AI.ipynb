# %% [markdown]
# # MultiModel (Image - Text gen)

# %%
import PIL.Image

img = PIL.Image.open(r'C:\Ds & AI ( my work)\AI\image.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=242x148>

# %%
from google import genai

# Create client
client = genai.Client(api_key="AIzaSyBEFlqbe8KKE5iCfD8tm-zSXBAB4Yq_RBM")

# Define the model
model = "gemini-2.5-flash"

# %%
response = client.models.generate_content(
    model=model,
    contents=[
        img,
        "Describe this image in detail"
    ]
)

print(response.text)
# Out:
# This image presents a stunning, dreamlike, and otherworldly landscape dominated by a vibrant palette of purples, blues, and pinks. It evokes a sense of cosmic wonder and mystical beauty.
#
# Here's a detailed breakdown:
#
# **Overall Impression:**
# The scene is a vast, open expanse under an intensely colorful, aurora-like sky. A single, dark, fantastical tree stands as a focal point, adorned with luminous, crystalline structures. A lone human figure stands small within this grand setting, emphasizing its immense scale and ethereal nature.
#
# **The Sky/Background:**
# The upper half of the image is dominated by a breathtaking celestial display. It's a swirling tapestry of nebulae and cosmic dust, featuring:
# *   **Intense Purples:** Deep indigo, rich violet, and softer lavender hues blend seamlessly.
# *   **Vibrant Pinks and Magentas:** Streaks and clouds of bright fuchsia and deep rose cut through the purples, particularly in the upper right, creating a dynamic, almost electric energy.
# *   **Deep Blues:** Hints of dark, starry blue appear in less illuminated sections, providing depth.
# *   **Stars:** Scattered sparsely across the darker regions, tiny pinpricks of light add to the cosmic feel, but the dominant feature is the glowing gas and light. The overall effect is that of a powerful, luminous aurora borealis or a distant galaxy.
#
# **The Central Tree-like Structure:**
# Standing tall and majestic in the mid-ground is a dark, gnarled, and ancient-looking tree or treelike entity.
# *   **Trunk and Branches:** The main trunk is thick and robust, with branches that twist and reach upwards, appearing dark, almost black, and silhouetted against the bright sky. It seems to be bare of leaves, enhancing its stark, sculptural quality.
# *   **Luminous Formations:** The most striking feature of the tree is the multitude of glowing, icicle-like or crystalline formations hanging from its branches. These appear to be translucent or crystalline, radiating a soft, pale blue, white, and hints of yellow light. They dangle downwards like ethereal chandeliers, creating an impression of magic or a unique, bioluminescent flora. Some appear to drip or melt with light.
# *   **Base Glow:** A subtle glow, similar to the hanging formations, emanates from the base of the tree, merging with the ground cover.
#
# **The Ground/Foreground:**
# The lower half of the image depicts an expansive, relatively flat plain or field:
# *   **
